max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668055383100486, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668767366597118, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670030833241374, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668817066723327, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668102483284503, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666903451696271, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666807213332504, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668955566516767, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666905226641878, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666998816654086, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667011421668576, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666923346638214, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667023871705169, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668940466964464, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669043150128952, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668857300343613, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668061000139765, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666904668333397, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668072467048965, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667003045004094, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668977849864555, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668007400100274, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668025933419508, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670061650317317, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668731066359518, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669025916295748, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666882553351267, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667033123327807, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667015316634206, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670349899989865, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669229866723374, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668839833194702, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670257450217225, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666809914992579, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667016368349626, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166682198997781, max=1.0))…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668118516584705, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666806006639187, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666811781663758, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666916923325819, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668151333093798, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669572433359765, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666876466673178, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666905834960441, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668769683262023, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666931593354093, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669035466717712, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668164366759206, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668823383224663, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666801596681277, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666872676675363, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667047744995216, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669079650212856, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668062633349714, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666876450035488, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668119700140475, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667011625007338, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668074700282885, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670094483318583, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670326950164356, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668914349672073, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666813318346006, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670090533443725, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668936883312804, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166690380666599, max=1.0))…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666890920023434, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666888994999075, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670069133397192, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666892146652875, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666809721646132, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670258516387548, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166680520332496, max=1.0))…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668049866954485, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667044656642247, max=1.0)…

# %%
run_experiment(dataset="SVHN", objective="ubt", predictor="wrn", generator="sg2", mix_dims=(0,8), interpolate=False)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666805094961698, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668068083527034, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666857351665385, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668902516539675, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666815049975412, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670190849981736, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668815966598534, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668802100078515, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668083983434674, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666813346625228, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668049849977253, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669194750041545, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668102399853522, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668092233400482, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668804550135974, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666894113344218, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668118833331393, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668893617073386, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669367583623775, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668946749996395, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668264833181942, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668779150253006, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668105466427125, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669183933117893, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668958050043634, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668131332941507, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016667974616575522, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670264283311552, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667020791695298, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668841966990536, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669101700244937, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666896334985116, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670067816933927, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667029693344375, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666811808342269, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666816638316959, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668913366447668, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666962525002115, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666883306655412, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666893819977607, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668895483599046, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668893650057727, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669178983526458, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668805783168258, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668114466786694, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668767950128918, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668058049981484, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668146300071386, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668812750140205, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668051749972317, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670471516651256, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666894648321128, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668058550082302, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670177016446058, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666904383309884, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668902666909464, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668075333291198, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166692515835166, max=1.0))…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670188150116397, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666744890001913, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668756782989173, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668121117011953, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666879761663343, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669147066325725, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667025040029936, max=1.0)…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670877483071913, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668772133319482, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668040816633343, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668241999771755, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668084450066088, max=1.0…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166688925329557, max=1.0))…
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668104216902672, max=1.0…
# Exception in thread SockSrvIntRdThr:
# Traceback (most recent call last):
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/server_sock.py", line 60, in run
#     result = self._iface.relay_q.get(timeout=1)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/multiprocessing/queues.py", line 117, in get
#     res = self._recv_bytes()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/multiprocessing/connection.py", line 421, in _recv_bytes
#     return self._recv(size)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# TypeError: an integer is required (got type NoneType)
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668070049975843, max=1.0…
# Traceback (most recent call last):
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/__main__.py", line 3, in <module>
#     cli.cli(prog_name="python -m wandb")
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/cli/cli.py", line 97, in wrapper
#     return func(*args, **kwargs)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/cli/cli.py", line 282, in service
#     server.serve()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/server.py", line 142, in serve
#     mux.loop()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 394, in loop
#     raise e
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 392, in loop
#     self._loop()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 385, in _loop
#     self._process_action(action)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 350, in _process_action
#     self._process_add(action)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 221, in _process_add
#     stream.start_thread(thread)
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 78, in start_thread
#     self._wait_thread_active()
#   File "/home/oliver/miniconda3/envs/neuralstyle/lib/python3.9/site-packages/wandb/sdk/service/streams.py", line 83, in _wait_thread_active
#     assert result
# AssertionError
# wandb: ERROR Error communicating with wandb process
# wandb: ERROR For more info see: https://docs.wandb.ai/library/init#init-start-error
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016671032499774203, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669191433175003, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670979466774347, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666881223306215, max=1.0)…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()

# %%
run_experiment(dataset="CIFAR10", objective="ubt", predictor="wrn", generator="sg2", mix_dims=(0,8), interpolate=False)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667019544984214, max=1.0)…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667001440024857, max=1.0)…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670749700278976, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668788783135824, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0166691496167914, max=1.0))…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667034853307996, max=1.0)…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670196916675196, max=1.0…
# ERROR:root:Raised error Error communicating with wandb process
# For more info see: https://docs.wandb.ai/library/init#init-start-error,
#  continuing...
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["w0_trials"]
# ERROR:root:You must call wandb.init() before wandb.summary["wn_trials"]
# Problem at: /home/oliver/PycharmProjects/NeuralStyle/src/_neural_tester.py 297 _init_wandb
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.log()
# ERROR:root:You must call wandb.init() before wandb.summary["expected_boundary"]
# ERROR:root:You must call wandb.init() before wandb.log()

# %% [markdown]
# ### Adversarial Boundary Testing

# %%
run_experiment(dataset="MNIST", objective="abt", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="FashionMNIST", objective="abt", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="SVHN", objective="abt", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="CIFAR10", objective="abt", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %% [markdown]
# ### Advesarial Testing

# %%
run_experiment(dataset="MNIST", objective="uat", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
#run_experiment(dataset="MNIST", objective="uat", predictor="wrn", generator="sg3", mix_dims=(1,15))

# %%
run_experiment(dataset="FashionMNIST", objective="uat", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="SVHN", objective="uat", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="CIFAR10", objective="uat", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
#run_experiment(dataset="CIFAR10", objective="uat", predictor="wrn", generator="sgXL", mix_dims=(1,15))

# %%
#run_experiment(dataset="Imagenet", objective="uat", predictor="wrn", generator="sgXL", mix_dims=(1,15))

# %% [markdown]
# ### Diversity Sampling

# %%
run_experiment(dataset="MNIST", objective="ds", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
#run_experiment(dataset="MNIST", objective="ds", predictor="wrn", generator="sg3", mix_dims=(1,15))

# %%
run_experiment(dataset="FashionMNIST", objective="ds", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="SVHN", objective="ds", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
run_experiment(dataset="CIFAR10", objective="ds", predictor="wrn", generator="sg2", mix_dims=(0,8))

# %%
#run_experiment(dataset="CIFAR10", objective="ds", predictor="wrn", generator="sgXL", mix_dims=(1,15))

# %%
#run_experiment(dataset="Imagenet", objective="ds", predictor="wrn", generator="sgXL", mix_dims=(1,15))
